# %%
import pandas as pd

# %%
df= pd.read_csv('speed_dating_data.csv')
df
# Out:
#       gender   age   income  goal  \
# 0          0  21.0  69487.0   2.0
# 1          0  21.0  69487.0   2.0
# 2          0  21.0  69487.0   2.0
# 3          0  21.0  69487.0   2.0
# 4          0  21.0  69487.0   2.0
# ...      ...   ...      ...   ...
# 8373       1  25.0      NaN   1.0
# 8374       1  25.0      NaN   1.0
# 8375       1  25.0      NaN   1.0
# 8376       1  25.0      NaN   1.0
# 8377       1  25.0      NaN   1.0
#
#                                                  career  dec  attr  sinc  \
# 0                                                lawyer    1   6.0   9.0
# 1                                                lawyer    1   7.0   8.0
# 2                                                lawyer    1   5.0   8.0
# 3                                                lawyer    1   7.0   6.0
# 4                                                lawyer    1   5.0   6.0
# ...                                                 ...  ...   ...   ...
# ...

# %%
df.columns #target: dec, features: income, attr, sinc, intel, fun, amb,
# Out:
# Index(['gender', 'age', 'income', 'goal', 'career', 'dec', 'attr', 'sinc',
#        'intel', 'fun', 'amb', 'shar', 'like', 'prob', 'met'],
#       dtype='object')

# %%
df['career'].unique()
# Out:
# array(['lawyer', 'law', 'Economist', 'lawyer/policy work', 'Law',
#        'Journalist', 'Congresswoman, and comedian',
#        'To create early childhood intervention programs',
#        'Academia, Research, Banking, Life', 'Corporate Lawyer', 'Lawyer',
#        'Corporate attorney', 'research/financial industry',
#        'academics or journalism', 'Financial Services', 'ceo', 'CEO',
#        'Undecided', 'Informatics', 'psychologist',
#        'health/nutrition oriented social worker', 'Social Worker',
#        'Social work with children', 'Speech Language Pathologist', nan,
#        'Social Work Administration', 'Professor', "Clidren's TV",
#        'Banking', 'Capital Markets', 'Biostatistics',
#        'Organizational Change Consultant', 'tech professional',
#        'Engineer', 'Academic', 'academia', 'banker / academia', 'banker',
#        'Music production', 'Entrepreneur',
#        'Intellectual Property Attorney', 'Medicine', 'consulting',
# ...

# %%
len(df['career'].unique())

# %%
df.shape
# Out:
# (8378, 15)

# %%
df.dtypes
# Out:
# gender      int64
# age       float64
# income    float64
# goal      float64
# career     object
# dec         int64
# attr      float64
# sinc      float64
# intel     float64
# fun       float64
# amb       float64
# shar      float64
# like      float64
# prob      float64
# met       float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender       0
# age         95
# income    4099
# goal        79
# career      89
# dec          0
# attr       202
# sinc       277
# intel      296
# fun        350
# amb        712
# shar      1067
# like       240
# prob       309
# met        375
# dtype: int64

# %%
num_nan_rows = df[['gender', 'age', 'income', 'career']].isna().all(axis=1).sum()
num_nan_rows
# Out:
# 0

# %%
df['id'] = df.set_index(['gender', 'age', 'income', 'career']).index.factorize()[0]+1
df
# Out:
#       gender   age   income  goal  \
# 0          0  21.0  69487.0   2.0
# 1          0  21.0  69487.0   2.0
# 2          0  21.0  69487.0   2.0
# 3          0  21.0  69487.0   2.0
# 4          0  21.0  69487.0   2.0
# ...      ...   ...      ...   ...
# 8373       1  25.0      NaN   1.0
# 8374       1  25.0      NaN   1.0
# 8375       1  25.0      NaN   1.0
# 8376       1  25.0      NaN   1.0
# 8377       1  25.0      NaN   1.0
#
#                                                  career  dec  attr  sinc  \
# 0                                                lawyer    1   6.0   9.0
# 1                                                lawyer    1   7.0   8.0
# 2                                                lawyer    1   5.0   8.0
# 3                                                lawyer    1   7.0   6.0
# 4                                                lawyer    1   5.0   6.0
# ...                                                 ...  ...   ...   ...
# ...

# %%
high_corrs = df.select_dtypes('number').corr() > 0.7
high_corrs
# no features seem to be highly correlated so no feature is excluded based on this criterion
# Out:
#         gender    age  income   goal    dec   attr   sinc  intel    fun  \
# gender    True  False   False  False  False  False  False  False  False
# age      False   True   False  False  False  False  False  False  False
# income   False  False    True  False  False  False  False  False  False
# goal     False  False   False   True  False  False  False  False  False
# dec      False  False   False  False   True   True  False  False   True
# attr     False  False   False  False   True   True   True   True   True
# sinc     False  False   False  False  False   True   True   True   True
# intel    False  False   False  False  False   True   True   True   True
# fun      False  False   False  False   True   True   True   True   True
# amb      False  False   False  False  False   True   True   True   True
# shar     False  False   False  False   True   True   True   True   True
# like     False  False   False  False   True   True   True   True   True
# ...

# %%
# dropping cols
# income -> too many missings
df_dropped = df.drop(columns=['income', 'goal', 'prob'])
